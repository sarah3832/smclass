# %%
import pandas as pd
df = pd.read_excel('score.xlsx',index_col='지원번호')

## 데이터 추가
df['합계'] = df['국어']+df['영어']+df['수학']+df['과학']+df['사회']
df['평균'] = df['합계']/5
df['결과'] = 'Fail'

# %% [markdown]
# 컬럼 순서변경

# %%
cols = list(df.columns)
cols
# Out:
# ['이름', '학교', '키', '국어', '영어', '수학', '과학', '사회', 'SW특기', '합계', '평균', '결과']

# %% [markdown]
# 컬럼이름 변경

# %%
# 컬럼이름 전체변경
df.columns = ['name','school','height','kor','eng','math','science','society','sw']

# 컬럼이름 변경
df.rename(columns={'이름':'name','학교':'school'})
df
df.rename(index={'1번':'no1'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 2
#       1 # 컬럼이름 전체변경
# ----> 2 df.columns = ['name','school','height','kor','eng','math','science','society','sw']
#       4 # 컬럼이름 변경
#       5 df.rename(columns={'이름':'name','학교':'school'})
#
# File c:\python\Lib\site-packages\pandas\core\generic.py:6313, in NDFrame.__setattr__(self, name, value)
#    6311 try:
#    6312     object.__getattribute__(self, name)
# -> 6313     return object.__setattr__(self, name, value)
#    6314 except AttributeError:
#    6315     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File c:\python\Lib\site-packages\pandas\core\generic.py:814, in NDFrame._set_axis(self, axis, labels)
#     809 """
#     810 This is called from the cython code when we set the `index` attribute
#     811 directly, e.g. `series.index = [1, 2, 3]`.
#     812 """
#     813 labels = ensure_index(labels)
# --> 814 self._mgr.set_axis(axis, labels)
#     815 self._clear_item_cache()
#
# File c:\python\Lib\site-packages\pandas\core\internals\managers.py:238, in BaseBlockManager.set_axis(self, axis, new_labels)
#     236 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     237     # Caller is responsible for ensuring we have an Index object.
# --> 238     self._validate_set_axis(axis, new_labels)
#     239     self.axes[axis] = new_labels
#
# File c:\python\Lib\site-packages\pandas\core\internals\base.py:98, in DataManager._validate_set_axis(self, axis, new_labels)
#      95     pass
#      97 elif new_len != old_len:
# ---> 98     raise ValueError(
#      99         f"Length mismatch: Expected axis has {old_len} elements, new "
#     100         f"values have {new_len} elements"
#     101     )
#
# ValueError: Length mismatch: Expected axis has 12 elements, new values have 9 elements

# %%
# cols[1:-1]  # 여러개 - list타입
# cols[-1]  # 1개 - 문자열
cols = list(df.columns)
# df[df.columns]

# df [이름,평균,학교:결과] - df[] 리스트타입만 가능
df = df[[cols[0]]+[cols[-1]]+cols[1:-1]]
df
# Out:
#        이름    결과    학교    키   국어   영어   수학  과학  사회        SW특기   합계    평균
# 지원번호
# 1번    강나래  Fail   구로고  197   90   85  100  95  85      Python  455  91.0
# 2번    강태원  Fail   구로고  184   40   35   50  55  25        Java  205  41.0
# 3번    강호림  Fail   구로고  168   80   75   70  80  75  Javascript  380  76.0
# 4번    김수찬  Fail   구로고  187   40   60   70  75  80         NaN  325  65.0
# 5번    김재욱  Fail   구로고  188   15   20   10  35  10         NaN   90  18.0
# 6번    박동현  Fail  디지털고  202   80  100   95  85  80           C  440  88.0
# 7번    박혜정  Fail  디지털고  188   55   65   45  40  35      PYTHON  240  48.0
# 8번    승근열  Fail  디지털고  190  100   85   90  95  95          C#  465  93.0
