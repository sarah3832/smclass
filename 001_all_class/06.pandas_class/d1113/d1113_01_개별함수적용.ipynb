# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
# 한글설정
# matplotlib.rcParams['font.family'] = 'AppleGothic'    # Mac용
matplotlib.rcParams['font.family'] = 'Malgun Gothic'    # Win용
matplotlib.rcParams['font.size'] = 15  # 글자크기
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_excel('score.xlsx',index_col='지원번호')

# %%
df.index
# Out:
# Index(['1번', '2번', '3번', '4번', '5번', '6번', '7번', '8번'], dtype='object', name='지원번호')

# %%
df['국어'][0]
# Out:
# C:\Users\KOSMO\AppData\Local\Temp\ipykernel_5460\3027529982.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df['국어'][0]
# np.int64(90)

# %%
n_list = [0,1,2,3,4,5,6,7]

# %%
plt.title('학생성적 그래프')
plt.plot(df.index,df['국어'],label='국어')
plt.plot(df.index,df['영어'],label='영어')
plt.plot(df.index,df['수학'],label='수학')

for i in range(8):
  plt.text(df.index[i],df['국어'][i]+0.6,df['국어'][i],ha='center')
  plt.text(df.index[i],df['영어'][i]+0.6,df['영어'][i],ha='center')
  plt.text(df.index[i],df['수학'][i]+0.6,df['수학'][i],ha='center')

plt.legend()
plt.show()
# Out:
# C:\Users\KOSMO\AppData\Local\Temp\ipykernel_5460\1001587196.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(df.index[i],df['국어'][i]+0.6,df['국어'][i],ha='center')
# C:\Users\KOSMO\AppData\Local\Temp\ipykernel_5460\1001587196.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(df.index[i],df['영어'][i]+0.6,df['영어'][i],ha='center')
# ...

# %%
x = [1,2,3]
y = [2,4,8]

plt.plot(x,y)

plt.text(x[0],y[0],y[0])
# Out:
# Text(1, 2, '2')

# %%
def n_func(x):
  if x-50 > 0:
    return x
  else:
    return 0

## apply : pandas 사용문법
df['국어'].apply(n_func)
# Out:
# 지원번호
# 1번     90
# 2번      0
# 3번     80
# 4번      0
# 5번      0
# 6번     80
# 7번     55
# 8번    100
# Name: 국어, dtype: int64

# %%
# 0이하의 숫자를 나타내기 위한 함수선언
def func(x):
  if x-30 < 0:
    return 0
  return x-30

# %%
# 누적막대 그래프
plt.figure(figsize=(8,4))
plt.title("학생성적 그래프")
plt.bar(df['이름'],df['국어'],width=0.6,label='국어')
plt.bar(df['이름'],df['영어'],bottom=df['국어'],width=0.6,label='영어')
plt.bar(df['이름'],df['수학'],bottom=df['국어']+df['영어'],width=0.6,label='수학')
# plt.legend(ncol=3)  # 가로형태
plt.legend()

n_list = df['국어'].apply(func)
for i in range(8):
  plt.text(df['이름'][i],n_list[i],df['국어'][i],ha='center')
  # plt.text(df['이름'][i],df['국어'][i]-30,df['국어'][i],ha='center')
  plt.text(df['이름'][i],df['국어'][i]+df['영어'][i]-30,df['영어'][i],ha='center')
  plt.text(df['이름'][i],df['국어'][i]+df['영어'][i]-30+df['수학'][i],df['수학'][i],ha='center')
# Out:
# C:\Users\KOSMO\AppData\Local\Temp\ipykernel_5460\1634414739.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(df['이름'][i],n_list[i],df['국어'][i],ha='center')
# C:\Users\KOSMO\AppData\Local\Temp\ipykernel_5460\1634414739.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(df['이름'][i],df['국어'][i]+df['영어'][i]-30,df['영어'][i],ha='center')
# ...

# %%
idx = np.arange(8)
idx
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %%
idx = np.arange(8)
w = 0.25
plt.bar(idx-w,df['국어'],width=w)
plt.bar(idx,df['영어'],width=w)
plt.bar(idx+w,df['수학'],width=w)
# plt.xlim(df['이름'])
# Out:
# <BarContainer object of 8 artists>
