# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
# 한글설정
# matplotlib.rcParams['font.family'] = 'AppleGothic'    # Mac용
matplotlib.rcParams['font.family'] = 'Malgun Gothic'    # Win용
matplotlib.rcParams['font.size'] = 15  # 글자크기
matplotlib.rcParams['axes.unicode_minus'] = False

df = pd.read_excel('score.xlsx',index_col='지원번호')

# %%
### 남자 인구현황 그래프 출력
df = pd.read_excel('연령별인구현황_202410.xlsx',skiprows=3,nrows=1,usecols='B,E:Y',index_col='행정기관')

### 여자 인구현황 그래프 출력
df2 = pd.read_excel('연령별인구현황_202410.xlsx',skiprows=3,nrows=1,usecols='B,AB:AV',index_col='행정기관')
# Out:
# c:\python\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\python\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
## row행 출력
# df.loc['전국  '][0]
# df.iloc[0][0]
# Out:
# C:\Users\KOSMO\AppData\Local\Temp\ipykernel_14560\3457603324.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.loc['전국  '][0]
# C:\Users\KOSMO\AppData\Local\Temp\ipykernel_14560\3457603324.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[0][0]
# 653516

# %%
df.columns
df.index
# 1. 데이터값, 천단위 표시제거, int타입 변경
df.iloc[0] = df.iloc[0].str.replace(",","").astype(int)

# 1. 데이터값, 천단위 표시제거, int타입 변경
df2.iloc[0] = df2.iloc[0].str.replace(",","").astype(int)

# %%
df.columns
df2.columns = df.columns
df2.columns
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
## 2. 남자만 가지고와서 세로막대그래프 출력

plt.figure(figsize=(13,7))
# x = df.columns
# y = df.iloc[0]//1000
plt.barh(df.columns,-df.iloc[0]//1000,label='남자')
plt.barh(df2.columns,df2.iloc[0]//1000,label='여자')
plt.title('2024년 인구현황')
plt.xlabel('인구수')
plt.ylabel('연령대')
plt.legend()
plt.show()

# %%
### 여자 인구현황
df2 = pd.read_excel('연령별인구현황_202410.xlsx',skiprows=3,nrows=1,usecols='B,AB:AV',index_col='행정기관')

df2.iloc[0] = df2.iloc[0].str.replace(",","").astype(int)

# x = df2.columns
# y = df2.iloc[0]//1000

plt.barh(df2.columns,df2.iloc[0]//1000)
# Out:
# c:\python\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# <BarContainer object of 21 artists>
